# %%
import os
import pandas as pd

# %%
df = pd.read_json(os.path.join('data_raw/2024-10-31','cd_Brno_Praha_D05_2024-10-31_23-48-16.json'))

# %%
df
# Out:
#       cena     den jizdni_doba               kam  \
# 0   479 Kč  středa   2:26 hod.  Praha-Holešovice
# 1   295 Kč  středa   2:54 hod.       Praha hl.n.
# 2   329 Kč  středa   2:47 hod.       Praha hl.n.
# 3   305 Kč  středa   3:04 hod.       Praha hl.n.
# 4   329 Kč  středa   2:34 hod.       Praha hl.n.
# 5   329 Kč  středa   3:44 hod.       Praha hl.n.
# 6   329 Kč  středa   2:34 hod.       Praha hl.n.
# 7   329 Kč  středa   3:07 hod.       Praha hl.n.
# 8   305 Kč  středa   2:32 hod.       Praha hl.n.
# 9   305 Kč  středa   3:44 hod.       Praha hl.n.
# 10  329 Kč  středa   2:32 hod.       Praha hl.n.
# 11  305 Kč  středa   3:07 hod.       Praha hl.n.
# 12  305 Kč  středa   2:32 hod.       Praha hl.n.
# 13  305 Kč  středa   3:44 hod.       Praha hl.n.
# 14  329 Kč  středa   2:32 hod.       Praha hl.n.
# 15  305 Kč  středa   3:07 hod.       Praha hl.n.
# 16  305 Kč  středa   2:32 hod.       Praha hl.n.
# 17  305 Kč  středa   3:44 hod.       Praha hl.n.
# ...
