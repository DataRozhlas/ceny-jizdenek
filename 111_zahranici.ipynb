# %%
import os
import pandas as pd
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 500)

# %%
df = pd.read_parquet(os.path.join('data','jizdenky.parquet'))

# %%
df = df[df['prostredek'] != 'autobus']
df = df[df['predstih_h'] >= 0]

# %%
def filtr(dopravce, mesto1, mesto2, mene_prisny=False):
    dfc = df.copy()
    dfc = dfc[dfc['prodejce'] == dopravce]
    dfc = dfc[dfc['odkud'].str.contains(mesto1) | dfc['kam'].str.contains(mesto1)]
    dfc = dfc[dfc['odkud'].str.contains(mesto2) | dfc['kam'].str.contains(mesto2)]
    minimum_prestupu = dfc['prestupy'].min()
    if minimum_prestupu == -1:
        minimum_prestupu = 0
    print(f"Nejmenší počet přestupů: {minimum_prestupu}.")
    minimum_casu = dfc['jizdni_doba'].min()
    print(f"Nejrychlejší jízdní doba: {minimum_casu} min.")
    if mene_prisny == True:
        minimum_prestupu += 1
    nasobek = 1.25
    if mene_prisny == True:
        nasobek = 1.5
    dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]
    dfc = dfc.drop_duplicates(subset=['odjezd','kam','predstih_d'], keep='last')
    return dfc.reset_index(drop=True)

# %%
filtr('ČD','Prah','Berl').groupby('predstih_d')['cena'].median().plot.bar(figsize=(25,5))
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 243.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
# <Axes: xlabel='predstih_d'>

# %%
filtr('ČD','Prah','Wars').groupby('predstih_d')['cena'].median().plot.bar(figsize=(25,5))
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 479.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
# <Axes: xlabel='predstih_d'>

# %%
filtr('ČD','Prah','Wien').groupby('predstih_d')['cena'].median().plot.bar(figsize=(25,5))
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 241.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
# <Axes: xlabel='predstih_d'>

# %%
filtr('RJ','Prah','Víde').groupby('predstih_d')['cena'].median().plot.bar(figsize=(25,5))
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 238.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
# <Axes: xlabel='predstih_d'>

# %%
filtr('ČD','Prah','Bratisl').groupby('predstih_d')['cena'].median().plot.bar(figsize=(25,5))
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 253.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
# <Axes: xlabel='predstih_d'>

# %%
filtr('ČD','Prah','Amster').groupby('predstih_d')['cena'].median().plot.bar(figsize=(25,5))
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 676.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
# <Axes: xlabel='predstih_d'>

# %%
filtr('ČD','Prah','Zagr').groupby('predstih_d')['cena'].median().plot.bar(figsize=(25,5))
# Out:
# Nejmenší počet přestupů: 1.
# Nejrychlejší jízdní doba: 663.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
# <Axes: xlabel='predstih_d'>

# %%
filtr('ČD','Prah','Bern').groupby('predstih_d')['cena'].median().plot.bar(figsize=(25,5))
# Out:
# Nejmenší počet přestupů: 1.
# Nejrychlejší jízdní doba: 678.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
# <Axes: xlabel='predstih_d'>

# %%
filtr('ČD','Prah','Buda').groupby('predstih_d')['cena'].median().plot.bar(figsize=(25,5))
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 401.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
# <Axes: xlabel='predstih_d'>

# %%
filtr('RJ','Prah','Víde').groupby('predstih_d')['cena'].median().plot.bar(figsize=(25,5))
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 238.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
# <Axes: xlabel='predstih_d'>

# %%
filtr('ČD','Ostrav','Gd').groupby('predstih_d')['cena'].median().plot.bar(figsize=(25,5))
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 429.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
# <Axes: xlabel='predstih_d'>

# %%
df[df['prodejce'] == 'LE'].groupby('kam').size()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\889392059.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df[df['prodejce'] == 'LE'].groupby('kam').size()
# kam
# Amsterdam Bijlmer ArenA                        0
# Amsterdam Centraal                             0
# Amsterdam Zuid                                 0
# Berlin Betriebsbf Schöneweide                  0
# Berlin Gesundbrunnen                           0
# Berlin Hbf                                     0
# Berlin Hbf (tief)                              0
# Berlin Ostbahnhof                              0
# Berlin Südkreuz                                0
# Berlin Zoologischer Garten                     0
# Berlin-Grünau                                  0
# Berlin-Lichtenberg                             0
# Berlin-Lichterfelde Ost                        0
# Bern                                           0
# Bratislava                                     0
# Bratislava hl.st.                              0
# Bratislava-Petržalka                           0
# Brno                                           0
# Brno hl.n.                                     0
# Bruxelles-Central                              0
# Bruxelles-Midi                                 0
# Budapest-Deli pu                               0
# Budapest-Kelenföld                             0
# Budapest-Nyugati pu                            0
# Budapešť                                       0
# Dresden Hbf                                    0
# Dresden-Neustadt                               0
# Flughafen BER - Terminal 5 (Schönefeld)        0
# Flughafen Wien                                 0
# Gdansk Glowny                                  0
# Hamburg Hbf                                    0
# Hamburg-Harburg                                0
# Jihlava                                        0
# Karlovy Vary                                   0
# Karlovy Vary dolní n.                          0
# Karlovy Vary, , terminál                       0
# Košice                                       792
# Krakov                                         0
# Krakow Business Park                           0
# Krakow Glowny                                  0
# Krakow Mydlniki                                0
# Kraków Główny                                188
# Liberec                                        0
# Ljubljana                                      0
# Olomouc                                        0
# Olomouc hl.n.                                  0
# Ostrava                                        0
# Ostrava hl.n.                               5403
# Ostrava-Svinov                              5403
# Pardubice hl.n.                              768
# Plzeň hl.n.                                    0
# Praha                                          0
# Praha Masarykovo n.                            0
# Praha hl.n.                                10289
# Praha-Holešovice                               0
# Praha-Libeň                                  248
# Praha-Smíchov                                  0
# Przemysl                                       0
# Przemysl Gl.                                   0
# Salzburg Hbf                                   0
# Slavonice                                      0
# Tanvald                                        0
# Vídeň                                          0
# Warszawa Centralna                             0
# Warszawa Wschodnia                             0
# Wien Franz-Josefs-Bahnhof                      0
# Wien Hbf                                       0
# Wien Stadlau                                   0
# Wien Stadlau Frachtenbahnhof                   0
# Zagreb Glavni kolodvor                         0
# Zürich HB                                      0
# Ústí n.L.hl.n.                                 0
# Ústí nad Labem hlavní nádraží                  0
# České Budějovice                               0
# Čop                                            0
# dtype: int64

# %%
filtr('LE','Pardub','Košice').groupby('predstih_d')['cena'].median().plot.bar(figsize=(25,5))
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 428.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
# <Axes: xlabel='predstih_d'>

# %%
filtr('LE','Prah','Krak').groupby('predstih_d')['cena'].median().plot.bar(figsize=(25,5))
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 344.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
# <Axes: xlabel='predstih_d'>

# %%
filtr('ČD','Brn','Hamb').groupby('predstih_d')['cena'].median().plot.bar(figsize=(25,5))
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 567.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
# <Axes: xlabel='predstih_d'>

# %%
filtr('ČD','Ústí','Dr').groupby('predstih_d')['cena'].median().plot.bar(figsize=(25,5))
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 40.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
# <Axes: xlabel='predstih_d'>

# %%
filtr('RJ','Pra','Buda').groupby('predstih_d')['cena'].median().plot.bar(figsize=(25,5))
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 399.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
# <Axes: xlabel='predstih_d'>

# %%
filtr('RJ','Pra','Čop').groupby('predstih_d')['cena'].median().plot.bar(figsize=(25,5))
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 645.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
# <Axes: xlabel='predstih_d'>

# %%
filtr('RJ','Pra','Kra').groupby('predstih_d')['cena'].median().plot.bar(figsize=(25,5))
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 348.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
# <Axes: xlabel='predstih_d'>

# %%
filtr('RJ','Pra','Koši').groupby('predstih_d')['cena'].median().plot.bar(figsize=(25,5))
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 489.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
# <Axes: xlabel='predstih_d'>

# %%
filtr('RJ','Brn','Víde').groupby('predstih_d')['cena'].median().plot.bar(figsize=(25,5))
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 87.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
# <Axes: xlabel='predstih_d'>

# %%
df[df['prodejce'] == 'RJ'].groupby('kam').size().nlargest(20)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2721501241.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df[df['prodejce'] == 'RJ'].groupby('kam').size().nlargest(20)
# kam
# Praha                            32629
# Brno                             23641
# Ostrava                          11945
# Vídeň                             6154
# Budapešť                          2686
# Bratislava                        2117
# Košice                            1092
# Čop                                364
# Krakov                             326
# Przemysl                           246
# Olomouc                            163
# Amsterdam Bijlmer ArenA              0
# Amsterdam Centraal                   0
# Amsterdam Zuid                       0
# Berlin Betriebsbf Schöneweide        0
# Berlin Gesundbrunnen                 0
# Berlin Hbf                           0
# Berlin Hbf (tief)                    0
# Berlin Ostbahnhof                    0
# Berlin Südkreuz                      0
# dtype: int64

# %%
brl = filtr('ČD','Prah','Berl').groupby('predstih_d')['cena'].agg(list).reset_index()
brl
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 243.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
#     predstih_d                                               cena
# 0            0  [2172.0, 1393.0, 1393.0, 1522.0, 2172.0, 2172....
# 1            1  [1393.0, 877.0, 1006.0, 1393.0, 1006.0, 903.0,...
# 2            2  [1522.0, 903.0, 1006.0, 1006.0, 1006.0, 1393.0...
# 3            3  [903.0, 903.0, 1006.0, 1006.0, 903.0, 903.0, 1...
# 4            4  [1006.0, 1522.0, 1522.0, 1522.0, 1522.0, 1006....
# 5            5  [1006.0, 903.0, 903.0, 748.0, 748.0, 1006.0, 1...
# 6            6  [387.0, 1006.0, 1006.0, 1264.0, 1393.0, 1393.0...
# 7            7  [387.0, 1006.0, 748.0, 748.0, 903.0, 903.0, 74...
# 8            8  [387.0, 748.0, 903.0, 903.0, 903.0, 748.0, 903...
# 9            9  [387.0, 903.0, 1006.0, nan, 1393.0, 1522.0, 13...
# 10          10  [1393.0, 1006.0, 748.0, 903.0, 903.0, 903.0, 1...
# 11          11  [1393.0, 1393.0, 903.0, 1522.0, 903.0, 1006.0,...
# 12          12  [748.0, 1522.0, 903.0, 903.0, 748.0, 748.0, 15...
# 13          13  [1006.0, nan, 1006.0, 748.0, 748.0, 903.0, 903...
# 14          14  [748.0, 748.0, 748.0, 748.0, 903.0, 903.0, 903...
# 15          15  [748.0, 748.0, 748.0, 748.0, 387.0, 748.0, 748...
# 16          16  [903.0, 748.0, 903.0, 748.0, 748.0, 748.0, 748...
# 17          17  [903.0, 1006.0, 1006.0, 903.0, 748.0, 903.0, 7...
# 18          18  [748.0, 1393.0, 1264.0, 1006.0, 1006.0, 1006.0...
# 19          19  [1264.0, 1006.0, 1006.0, 1006.0, 903.0, 748.0,...
# 20          20  [748.0, 748.0, 903.0, 748.0, 748.0, 748.0, 748...
# 21          21  [387.0, 748.0, 748.0, 748.0, 748.0, 748.0, nan...
# 22          22  [903.0, 903.0, 903.0, 1006.0, 748.0, 903.0, 10...
# 23          23  [748.0, 903.0, 748.0, 903.0, 748.0, 748.0, 387...
# 24          24  [903.0, 903.0, 903.0, 903.0, 1006.0, 748.0, 10...
# 25          25  [1393.0, 1006.0, 1393.0, 1393.0, 1006.0, 903.0...
# 26          26  [1522.0, 1006.0, 748.0, 748.0, 748.0, 748.0, 7...
# 27          27  [748.0, 903.0, nan, 1006.0, 748.0, 748.0, 1006...
# 28          28  [748.0, 748.0, 748.0, 748.0, 748.0, 1006.0, 10...
# 29          29  [877.0, 903.0, 903.0, 748.0, 1006.0, 903.0, 90...
# 30          30  [748.0, 748.0, 748.0, 748.0, 903.0, 748.0, 748...
# 31          31  [nan, 748.0, 748.0, 903.0, 903.0, 1006.0, 903....
# 32          32  [nan, 748.0, 748.0, 748.0, 1006.0, 748.0, 2172...
# 33          33  [748.0, 748.0, 1522.0, 1393.0, 387.0, 1006.0, ...
# 34          34  [1006.0, nan, 903.0, 903.0, 748.0, 387.0, 1006...
# 35          35  [1006.0, 748.0, 748.0, 748.0, 748.0, 1006.0, n...
# 36          36  [1135.0, 748.0, 903.0, 748.0, 748.0, 903.0, 90...
# 37          37  [1006.0, 1393.0, 1006.0, 903.0, 903.0, 1006.0,...
# 38          38  [748.0, 1006.0, 903.0, 748.0, 748.0, 1522.0, 1...
# 39          39  [nan, 903.0, 748.0, 903.0, 748.0, 748.0, 748.0...
# 40          40  [748.0, 748.0, 748.0, 387.0, 903.0, 1006.0, 15...
# 41          41  [387.0, 748.0, 748.0, 748.0, 1006.0, 387.0, 90...
# 42          42  [nan, 387.0, 748.0, 748.0, 748.0, 748.0, 748.0...
# 43          43  [748.0, nan, 748.0, 748.0, 748.0, 387.0, 748.0...
# 44          44  [748.0, 748.0, 748.0, 748.0, 748.0, 748.0, 748...
# 45          45  [748.0, 903.0, 748.0, 387.0, 903.0, 748.0, 748...
# 46          46  [387.0, nan, 748.0, 748.0, 748.0, 748.0, 748.0...
# 47          47  [387.0, nan, 748.0, 903.0, 748.0, 903.0, 748.0...
# 48          48  [748.0, 903.0, 903.0, 748.0, 748.0, nan, 903.0...
# 49          49  [903.0, 903.0, 748.0, 748.0, 748.0, 748.0, 903...
# 50          50  [748.0, 748.0, 387.0, 748.0, 748.0, 903.0, nan...
# 51          51  [748.0, 748.0, nan, 387.0, 903.0, 903.0, 748.0...
# 52          52  [748.0, nan, 387.0, 748.0, 748.0, 903.0, 903.0...
# 53          53  [903.0, 387.0, 903.0, 1006.0, 748.0, 903.0, 74...
# 54          54  [1006.0, 903.0, 387.0, 748.0, 748.0, 748.0, 74...
# 55          55  [748.0, 748.0, 387.0, 748.0, 748.0, 748.0, 748...
# 56          56  [748.0, 903.0, 387.0, 748.0, 748.0, 748.0, 748...
# 57          57  [748.0, 748.0, 903.0, 748.0, 1006.0, 748.0, 38...
# 58          58  [387.0, 748.0, 748.0, 748.0, 748.0, 748.0, 748...
# 59          59  [748.0, 748.0, 748.0, 387.0, 748.0, 748.0, 748...
# 60          60  [748.0, 748.0, 748.0, 748.0, 748.0, 387.0, 748...
# 61          61  [748.0, 748.0, 748.0, 387.0, 748.0, 748.0, 748...
# 62          62  [748.0, 748.0, 387.0, 748.0, 748.0, 748.0, 748...
# 63          63  [748.0, 748.0, 748.0, 748.0, 748.0, 748.0, 387...
# 64          64  [748.0, 748.0, 748.0, 748.0, 748.0, 387.0, 387...
# 65          65  [387.0, 748.0, 748.0, 748.0, 387.0, 748.0, 748...
# 66          66  [387.0, 748.0, 748.0, 748.0, 748.0, 748.0, 387...
# 67          67  [748.0, 387.0, 748.0, 748.0, 748.0, 748.0, 748...
# 68          68  [748.0, 748.0, 748.0, 748.0, 748.0, 748.0, 387...
# 69          69  [748.0, 748.0, 748.0, 387.0, 748.0, 748.0, 748...
# 70          70  [387.0, 748.0, 748.0, 748.0, 748.0, 748.0, 748...
# 71          71  [748.0, 748.0, 748.0, 748.0, 748.0, 387.0, 748...
# 72          72  [387.0, 748.0, 748.0, 748.0, 748.0, 748.0, 387...
# 73          73  [387.0, 748.0, 748.0, 748.0, 748.0, 387.0, 748...
# 74          74  [748.0, 748.0, 748.0, 748.0, 748.0, 387.0, 748...
# 75          75  [748.0, 748.0, 748.0, 387.0, 748.0, 748.0, 748...
# 76          76  [748.0, 748.0, 748.0, 748.0, 748.0, 387.0, 748...
# 77          77  [748.0, 748.0, 748.0, 748.0, 748.0, 387.0, 748...
# 78          78  [748.0, 748.0, 748.0, 748.0, 748.0, 387.0, 748...
# 79          79  [748.0, 748.0, 748.0, 748.0, 387.0, 748.0, 748...
# 80          80  [748.0, 748.0, 748.0, 748.0, 748.0, 748.0, 387...
# 81          81  [387.0, 748.0, 748.0, 748.0, 748.0, 748.0, 748...
# 82          82  [748.0, 748.0, 748.0, 387.0, 748.0, 748.0, 748...
# 83          83  [748.0, 748.0, 748.0, 748.0, 387.0, 748.0, 748...
# 84          84  [748.0, 387.0, 748.0, 387.0, 748.0, 748.0, 748...
# 85          85  [387.0, 748.0, 748.0, 748.0, 748.0, 748.0, 748...
# 86          86                                            [748.0]
# 87          88  [748.0, 748.0, 748.0, 748.0, 748.0, 387.0, 748...
# 88          89  [748.0, 748.0, 387.0, 748.0, 748.0, 748.0, 748...
# 89          90  [748.0, nan, nan, nan, 748.0, 748.0, 748.0, 74...
# 90          91                               [nan, nan, nan, nan]

# %%
brl.explode('cena').plot.scatter(x="predstih_d",y="cena")
# Out:
# <Axes: xlabel='predstih_d', ylabel='cena'>

# %%
filtr('ČD','Prah','Lju').groupby('predstih_d')['cena'].agg(list).reset_index().explode('cena').plot.scatter(x="predstih_d",y="cena")
# Out:
# Nejmenší počet přestupů: 1.
# Nejrychlejší jízdní doba: 578.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
# <Axes: xlabel='predstih_d', ylabel='cena'>

# %%
filtr('ČD','Prah','Wars').groupby('predstih_d')['cena'].agg(list).reset_index().explode('cena').plot.scatter(x="predstih_d",y="cena")
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 479.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
# <Axes: xlabel='predstih_d', ylabel='cena'>

# %%
filtr('RJ','Prah','Čop').groupby('predstih_d')['cena'].agg(list).reset_index().explode('cena').plot.scatter(x="predstih_d",y="cena")
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 645.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
# <Axes: xlabel='predstih_d', ylabel='cena'>

# %%
filtr('RJ','Prah','Krak').groupby('predstih_d')['cena'].agg(list).reset_index().explode('cena').plot.scatter(x="predstih_d",y="cena")
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 348.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
# <Axes: xlabel='predstih_d', ylabel='cena'>

# %%
filtr('RJ','Prah','Víde').groupby('predstih_d')['cena'].agg(list).reset_index().explode('cena').plot.scatter(x="predstih_d",y="cena")
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 238.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]
# <Axes: xlabel='predstih_d', ylabel='cena'>

# %%
df_profiltr = df.drop_duplicates(subset=['odkud','kam','prodejce','odjezd','predstih_d'], keep='last')

# %%
(df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['prodejce'] == 'ČD')].groupby('kam')['cena'].max().dropna() / df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['prodejce'] == 'ČD')].groupby('kam')['cena'].min().dropna()).sort_values()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\1161192837.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['prodejce'] == 'ČD')].groupby('kam')['cena'].max().dropna() / df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['prodejce'] == 'ČD')].groupby('kam')['cena'].min().dropna()).sort_values()
# kam
# Berlin Ostbahnhof             1.000000
# Bratislava-Petržalka          1.000000
# Amsterdam Zuid                1.152273
# Budapest-Kelenföld            1.205611
# Plzeň hl.n.                   1.222857
# Berlin-Lichtenberg            1.542636
# Wien Franz-Josefs-Bahnhof     2.350797
# Brno hl.n.                    2.598513
# Ljubljana                     2.694856
# Zagreb Glavni kolodvor        2.698957
# Warszawa Wschodnia            2.725587
# Ostrava-Svinov                2.833910
# Bern                          2.888144
# Budapest-Nyugati pu           3.171617
# Berlin Gesundbrunnen          3.736602
# Bratislava hl.st.             3.965000
# Krakow Glowny                 4.094183
# Berlin Hbf                    4.381016
# Ostrava hl.n.                 4.525952
# Wien Hbf                      4.958656
# Bruxelles-Midi                5.368035
# Amsterdam Centraal            7.650460
# Berlin Südkreuz               8.467700
# Warszawa Centralna            8.824490
# Berlin Hbf (tief)            13.387597
# Name: cena, dtype: float64

# %%
(df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['prodejce'] == 'ČD')].groupby('kam')['cena'].max().dropna() / df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['prodejce'] == 'ČD')].groupby('kam')['cena'].min().dropna()).sort_values().median()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2506272798.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['prodejce'] == 'ČD')].groupby('kam')['cena'].max().dropna() / df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['prodejce'] == 'ČD')].groupby('kam')['cena'].min().dropna()).sort_values().median()
# 2.8881441139505655

# %%
df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['prodejce'] == 'ČD')].groupby('kam')['cena'].max().dropna()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\3723333828.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['prodejce'] == 'ČD')].groupby('kam')['cena'].max().dropna()
# kam
# Amsterdam Centraal           11644.0
# Amsterdam Zuid                6311.0
# Berlin Gesundbrunnen          3277.0
# Berlin Hbf                    3277.0
# Berlin Hbf (tief)             5181.0
# Berlin Ostbahnhof             4149.0
# Berlin Südkreuz               3277.0
# Berlin-Lichtenberg            1393.0
# Bern                          6894.0
# Bratislava hl.st.             1586.0
# Bratislava-Petržalka          2085.0
# Brno hl.n.                     699.0
# Bruxelles-Midi                7322.0
# Budapest-Kelenföld            3008.0
# Budapest-Nyugati pu           1922.0
# Krakow Glowny                 1478.0
# Ljubljana                     3824.0
# Ostrava hl.n.                 1308.0
# Ostrava-Svinov                 819.0
# Plzeň hl.n.                    428.0
# Warszawa Centralna            4324.0
# Warszawa Wschodnia            2205.0
# Wien Franz-Josefs-Bahnhof     1032.0
# Wien Hbf                      1919.0
# Zagreb Glavni kolodvor        3622.0
# Name: cena, dtype: float64

# %%
df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['prodejce'] == 'ČD')].groupby('kam')['cena'].min().dropna()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2921589089.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['prodejce'] == 'ČD')].groupby('kam')['cena'].min().dropna()
# kam
# Amsterdam Centraal           1522.0
# Amsterdam Zuid               5477.0
# Berlin Gesundbrunnen          877.0
# Berlin Hbf                    748.0
# Berlin Hbf (tief)             387.0
# Berlin Ostbahnhof            4149.0
# Berlin Südkreuz               387.0
# Berlin-Lichtenberg            903.0
# Bern                         2387.0
# Bratislava hl.st.             400.0
# Bratislava-Petržalka         2085.0
# Brno hl.n.                    269.0
# Bruxelles-Midi               1364.0
# Budapest-Kelenföld           2495.0
# Budapest-Nyugati pu           606.0
# Krakow Glowny                 361.0
# Ljubljana                    1419.0
# Ostrava hl.n.                 289.0
# Ostrava-Svinov                289.0
# Plzeň hl.n.                   350.0
# Warszawa Centralna            490.0
# Warszawa Wschodnia            809.0
# Wien Franz-Josefs-Bahnhof     439.0
# Wien Hbf                      387.0
# Zagreb Glavni kolodvor       1342.0
# Name: cena, dtype: float64

# %%
(df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['prodejce'] == 'ČD') & (df_profiltr['predstih_d'] == 0)].groupby('kam')['cena'].median().dropna() / df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['prodejce'] == 'ČD') & (df_profiltr['predstih_d'] == 3)].groupby('kam')['cena'].median().dropna()).sort_values()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\3948622527.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['prodejce'] == 'ČD') & (df_profiltr['predstih_d'] == 0)].groupby('kam')['cena'].median().dropna() / df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['prodejce'] == 'ČD') & (df_profiltr['predstih_d'] == 3)].groupby('kam')['cena'].median().dropna()).sort_values()
# kam
# Ostrava-Svinov               0.889543
# Amsterdam Centraal           1.000000
# Warszawa Wschodnia           1.000000
# Ljubljana                    1.000000
# Budapest-Nyugati pu          1.000000
# Bruxelles-Midi               1.000000
# Brno hl.n.                   1.000000
# Bratislava-Petržalka         1.000000
# Budapest-Kelenföld           1.000000
# Berlin Gesundbrunnen         1.000000
# Amsterdam Zuid               1.000000
# Plzeň hl.n.                  1.027473
# Ostrava hl.n.                1.128968
# Bratislava hl.st.            1.142405
# Warszawa Centralna           1.151868
# Bern                         1.166407
# Krakow Glowny                1.192250
# Berlin-Lichtenberg           1.384692
# Berlin Hbf                   1.384692
# Wien Hbf                     1.400000
# Berlin Hbf (tief)            1.512922
# Wien Franz-Josefs-Bahnhof    2.027335
# Zagreb Glavni kolodvor       2.698957
# Name: cena, dtype: float64

# %%
(df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['prodejce'] == 'ČD') & (df_profiltr['predstih_d'] == 0)].groupby('kam')['cena'].median().dropna() / df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['prodejce'] == 'ČD') & (df_profiltr['predstih_d'].isin(range(21,28)))].groupby('kam')['cena'].median().dropna()).sort_values()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\3111298776.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['prodejce'] == 'ČD') & (df_profiltr['predstih_d'] == 0)].groupby('kam')['cena'].median().dropna() / df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['prodejce'] == 'ČD') & (df_profiltr['predstih_d'].isin(range(21,28)))].groupby('kam')['cena'].median().dropna()).sort_values()
# kam
# Amsterdam Centraal           1.000000
# Bratislava-Petržalka         1.000000
# Bruxelles-Midi               1.000000
# Budapest-Kelenföld           1.000000
# Plzeň hl.n.                  1.027473
# Brno hl.n.                   1.091185
# Bern                         1.166407
# Krakow Glowny                1.192250
# Ostrava hl.n.                1.213220
# Ostrava-Svinov               1.222672
# Budapest-Nyugati pu          1.295552
# Warszawa Wschodnia           1.510507
# Warszawa Centralna           1.533592
# Berlin Hbf (tief)            1.685493
# Wien Hbf                     1.750000
# Bratislava hl.st.            1.805000
# Berlin Hbf                   1.862299
# Wien Franz-Josefs-Bahnhof    2.027335
# Ljubljana                    2.150238
# Zagreb Glavni kolodvor       2.698957
# Amsterdam Zuid                    NaN
# Berlin Gesundbrunnen              NaN
# Berlin Ostbahnhof                 NaN
# Berlin Südkreuz                   NaN
# Berlin-Lichtenberg                NaN
# Name: cena, dtype: float64

# %%
(df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['prodejce'] == 'ČD') & (df_profiltr['predstih_d'] == 0)].groupby('kam')['cena'].median().dropna() / df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['prodejce'] == 'ČD') & (df_profiltr['predstih_d'].isin(range(8,15)))].groupby('kam')['cena'].median().dropna()).sort_values()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2307555228.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['prodejce'] == 'ČD') & (df_profiltr['predstih_d'] == 0)].groupby('kam')['cena'].median().dropna() / df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['prodejce'] == 'ČD') & (df_profiltr['predstih_d'].isin(range(8,15)))].groupby('kam')['cena'].median().dropna()).sort_values()
# kam
# Amsterdam Zuid               0.867850
# Amsterdam Centraal           1.000000
# Plzeň hl.n.                  1.000000
# Ostrava-Svinov               1.000000
# Budapest-Kelenföld           1.000000
# Brno hl.n.                   1.000000
# Bratislava-Petržalka         1.000000
# Bruxelles-Midi               1.000000
# Krakow Glowny                1.192250
# Ostrava hl.n.                1.213220
# Budapest-Nyugati pu          1.295552
# Wien Hbf                     1.400000
# Bratislava hl.st.            1.473469
# Warszawa Centralna           1.483750
# Berlin Hbf (tief)            1.512922
# Berlin-Lichtenberg           1.542636
# Berlin Hbf                   1.542636
# Wien Franz-Josefs-Bahnhof    2.027335
# Ljubljana                    2.150238
# Berlin Gesundbrunnen         2.368301
# Bern                         2.416633
# Zagreb Glavni kolodvor       2.698957
# Warszawa Wschodnia                NaN
# Name: cena, dtype: float64

# %%
(df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['predstih_d'] == 0)].groupby('kam')['cena'].median().dropna() / df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['predstih_d'].isin(range(8,15)))].groupby('kam')['cena'].median().dropna()).sort_values()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2031535851.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['predstih_d'] == 0)].groupby('kam')['cena'].median().dropna() / df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['predstih_d'].isin(range(8,15)))].groupby('kam')['cena'].median().dropna()).sort_values()
# kam
# Amsterdam Zuid               0.867850
# Amsterdam Centraal           1.000000
# Tanvald                      1.000000
# Plzeň hl.n.                  1.000000
# Ostrava                      1.000000
# Krakov                       1.000000
# České Budějovice             1.000000
# Budapešť                     1.000000
# Budapest-Kelenföld           1.000000
# Bruxelles-Midi               1.000000
# Brno hl.n.                   1.000000
# Košice                       1.000000
# Bratislava-Petržalka         1.000000
# Brno                         1.000000
# Bratislava                   1.000000
# Vídeň                        1.009107
# Čop                          1.100200
# Kraków Główny                1.187647
# Krakow Glowny                1.192250
# Ostrava hl.n.                1.213220
# Budapest-Nyugati pu          1.295552
# Wien Hbf                     1.400000
# Ostrava-Svinov               1.455581
# Bratislava hl.st.            1.473469
# Warszawa Centralna           1.483750
# Berlin Hbf (tief)            1.512922
# Berlin-Lichtenberg           1.542636
# Berlin Hbf                   1.542636
# Wien Franz-Josefs-Bahnhof    2.027335
# Ljubljana                    2.150238
# Berlin Gesundbrunnen         2.368301
# Bern                         2.416633
# Zagreb Glavni kolodvor       2.698957
# Warszawa Wschodnia                NaN
# Name: cena, dtype: float64

# %%
(df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['predstih_d'] <= 1)].groupby('kam')['cena'].median().dropna() / df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['predstih_d'].isin(range(14,22)))].groupby('kam')['cena'].median().dropna()).sort_values()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2940320240.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['predstih_d'] <= 1)].groupby('kam')['cena'].median().dropna() / df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['predstih_d'].isin(range(14,22)))].groupby('kam')['cena'].median().dropna()).sort_values()
# kam
# Amsterdam Zuid               0.867850
# Brno                         0.882006
# Vídeň                        0.916528
# Amsterdam Centraal           1.000000
# Tanvald                      1.000000
# Ostrava                      1.000000
# Krakov                       1.000000
# České Budějovice             1.000000
# Budapešť                     1.000000
# Budapest-Kelenföld           1.000000
# Bruxelles-Midi               1.000000
# Košice                       1.000000
# Bratislava-Petržalka         1.000000
# Bratislava                   1.000000
# Plzeň hl.n.                  1.027473
# Brno hl.n.                   1.091185
# Čop                          1.100200
# Krakow Glowny                1.192250
# Ostrava hl.n.                1.213220
# Berlin Hbf                   1.256921
# Kraków Główny                1.261628
# Bratislava hl.st.            1.289796
# Budapest-Nyugati pu          1.295552
# Berlin Hbf (tief)            1.384692
# Wien Hbf                     1.400000
# Zagreb Glavni kolodvor       1.418033
# Warszawa Centralna           1.483750
# Ostrava-Svinov               1.495050
# Bern                         1.808316
# Wien Franz-Josefs-Bahnhof    2.027335
# Ljubljana                    2.150238
# Berlin Gesundbrunnen         3.736602
# Berlin Ostbahnhof                 NaN
# Berlin Südkreuz                   NaN
# Berlin-Lichtenberg                NaN
# Warszawa Wschodnia                NaN
# Name: cena, dtype: float64

# %%
(df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['predstih_d'] <= 1)].groupby('kam')['cena'].min().dropna() / df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['predstih_d'].isin(range(14,22)))].groupby('kam')['cena'].min().dropna()).sort_values()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\917741310.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['predstih_d'] <= 1)].groupby('kam')['cena'].min().dropna() / df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['predstih_d'].isin(range(14,22)))].groupby('kam')['cena'].min().dropna()).sort_values()
# kam
# Tanvald                      0.300000
# Brno                         0.553073
# Amsterdam Centraal           0.595928
# Amsterdam Zuid               0.867850
# Vídeň                        1.000000
# Ostrava                      1.000000
# Krakov                       1.000000
# České Budějovice             1.000000
# Budapešť                     1.000000
# Budapest-Kelenföld           1.000000
# Košice                       1.000000
# Čop                          1.000000
# Bratislava-Petržalka         1.000000
# Bratislava hl.st.            1.000000
# Bratislava                   1.000000
# Berlin Gesundbrunnen         1.000000
# Brno hl.n.                   1.000000
# Plzeň hl.n.                  1.027473
# Bern                         1.080855
# Ljubljana                    1.145173
# Zagreb Glavni kolodvor       1.153502
# Berlin Hbf                   1.172460
# Bruxelles-Midi               1.304985
# Kraków Główny                1.333626
# Budapest-Nyugati pu          1.490099
# Wien Hbf                     1.666667
# Ostrava hl.n.                1.710059
# Ostrava-Svinov               1.769231
# Wien Franz-Josefs-Bahnhof    2.027335
# Warszawa Centralna           2.159184
# Krakow Glowny                2.216066
# Berlin Hbf (tief)            2.333333
# Berlin Ostbahnhof                 NaN
# Berlin Südkreuz                   NaN
# Berlin-Lichtenberg                NaN
# Warszawa Wschodnia                NaN
# Name: cena, dtype: float64

# %%
(df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['predstih_d'] <= 1)].groupby('kam')['cena'].max().dropna() / df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['predstih_d'].isin(range(14,22)))].groupby('kam')['cena'].max().dropna()).sort_values()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\3187331978.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['predstih_d'] <= 1)].groupby('kam')['cena'].max().dropna() / df_profiltr[df_profiltr['odkud'].str.contains('Prah') & (df_profiltr['predstih_d'].isin(range(14,22)))].groupby('kam')['cena'].max().dropna()).sort_values()
# kam
# Berlin Hbf (tief)            0.632503
# Budapešť                     0.777432
# Košice                       0.831888
# Amsterdam Zuid               0.867850
# Krakov                       0.898876
# Zagreb Glavni kolodvor       1.000000
# Wien Franz-Josefs-Bahnhof    1.000000
# Vídeň                        1.000000
# Tanvald                      1.000000
# Ljubljana                    1.000000
# České Budějovice             1.000000
# Budapest-Nyugati pu          1.000000
# Amsterdam Centraal           1.000000
# Bruxelles-Midi               1.000000
# Berlin Hbf                   1.000000
# Bern                         1.000000
# Čop                          1.000000
# Bratislava-Petržalka         1.000000
# Krakow Glowny                1.001355
# Budapest-Kelenföld           1.011432
# Wien Hbf                     1.090781
# Bratislava hl.st.            1.138550
# Plzeň hl.n.                  1.144385
# Ostrava hl.n.                1.175348
# Ostrava-Svinov               1.175348
# Bratislava                   1.187735
# Brno hl.n.                   1.282569
# Ostrava                      1.293967
# Kraków Główny                1.340993
# Warszawa Centralna           1.687085
# Brno                         1.702660
# Berlin Gesundbrunnen         3.736602
# Berlin Ostbahnhof                 NaN
# Berlin Südkreuz                   NaN
# Berlin-Lichtenberg                NaN
# Warszawa Wschodnia                NaN
# Name: cena, dtype: float64

# %%
from tm3k import irozhlas_graf
# Out:
# C:\Users\micha\projekty\ceny-jizdenek\tm3k\tm3k_utils.py:322: SyntaxWarning: invalid escape sequence '\s'
#   df_tabulka = re.sub("\\n\s*", "", df_tabulka.to_html(index=False))
# C:\Users\micha\projekty\ceny-jizdenek\tm3k\tm3k_utils.py:351: SyntaxWarning: invalid escape sequence '\('
#   df_tabulka = re.sub("\([\d]*\)", "", df_tabulka)

# %%
cd_gdansk = filtr('ČD','Ostrava','Gda')
print(f"Řádků tabulky: {len(cd_gdansk)}.")
cd_gdansk = pd.Series(cd_gdansk.groupby('predstih_d')['cena'].median(), name="ČD Ostrava - Gdaňsk").head(60)
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 429.0 min.
# Řádků tabulky: 249.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]

# %%
cd_berlin = filtr('ČD','Praha','Berl')
print(f"Řádků tabulky: {len(cd_berlin)}.")
cd_berlin = pd.Series(cd_berlin.groupby('predstih_d')['cena'].median(), name="ČD Praha - Berlín").head(60)
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 243.0 min.
# Řádků tabulky: 6367.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]

# %%
cd_brusel = filtr('ČD','Praha','Bru',mene_prisny=True)
print(f"Řádků tabulky: {len(cd_brusel)}.")
cd_brusel = pd.Series(cd_brusel.groupby('predstih_d')['cena'].median(), name="ČD Praha - Brusel").head(60)
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 653.0 min.
# Řádků tabulky: 177.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]

# %%
cd_bratislava = filtr('ČD','Praha','Bratisl')
print(f"Řádků tabulky: {len(cd_bratislava)}.")
cd_bratislava = pd.Series(cd_bratislava.groupby('predstih_d')['cena'].median(), name="ČD Praha - Bratislava").head(60)
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 253.0 min.
# Řádků tabulky: 7272.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]

# %%
cd_budapest = filtr('ČD','Praha','Budap')
print(f"Řádků tabulky: {len(cd_budapest)}.")
cd_budapest = pd.Series(cd_budapest.groupby('predstih_d')['cena'].median(), name="ČD Praha - Budapešť").head(60)
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 401.0 min.
# Řádků tabulky: 5377.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]

# %%
rj_viden = filtr('RJ','Praha','Víde')
print(f"Řádků tabulky: {len(rj_viden)}.")
rj_viden = pd.Series(rj_viden.groupby('predstih_d')['cena'].median(), name="RJ Praha - Vídeň").head(60)
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 238.0 min.
# Řádků tabulky: 1527.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]

# %%
cd_viden = filtr('ČD','Praha hl.n.','Wien')
print(f"Řádků tabulky: {len(cd_viden)}.")
cd_viden = pd.Series(cd_viden.groupby('predstih_d')['cena'].median(), name="ČD Praha - Vídeň").head(60)
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 241.0 min.
# Řádků tabulky: 5233.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]

# %%
le_kosice = filtr('LE','Pardu','Koši')
print(f"Řádků tabulky: {len(le_kosice)}.")
le_kosice = pd.Series(le_kosice.groupby('predstih_d')['cena'].median(), name="LE Pardubice - Košice").head(60)
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 428.0 min.
# Řádků tabulky: 854.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]

# %%
le_krakov = filtr('LE','Praha','Krak')
print(f"Řádků tabulky: {len(le_krakov)}.")
le_krakov = pd.Series(le_krakov.groupby('predstih_d')['cena'].median(), name="LE Praha - Krakov").head(60)
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 344.0 min.
# Řádků tabulky: 214.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]

# %%
cd_varsava = filtr('ČD','Praha hl.n.','Warszawa Centralna')
print(f"Řádků tabulky: {len(cd_varsava)}.")
cd_varsava = pd.Series(cd_varsava.groupby('predstih_d')['cena'].median(), name="ČD Praha - Varšava").head(60)
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 479.0 min.
# Řádků tabulky: 2050.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]

# %%
rj_cop = filtr('RJ','Praha','Čop')
print(f"Řádků tabulky: {len(rj_cop)}.")
rj_cop = pd.Series(rj_cop.groupby('predstih_d')['cena'].median(), name="RJ Praha - Čop (Ukrajina)").head(60)
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 645.0 min.
# Řádků tabulky: 270.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]

# %%
rj_bratislava = filtr('RJ','Praha','Brati')
print(f"Řádků tabulky: {len(rj_bratislava)}.")
rj_bratislava = pd.Series(rj_bratislava.groupby('predstih_d')['cena'].median(), name="RJ Praha - Bratislava").head(60)
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 250.0 min.
# Řádků tabulky: 1755.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\134202732.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * 1.25))]

# %%
df[df['kam'].str.contains('Brati')].groupby(["prodejce",'odkud']).size().nlargest()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\1245679331.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df[df['kam'].str.contains('Brati')].groupby(["prodejce",'odkud']).size().nlargest()
# prodejce  odkud
# ČD        Praha hl.n.         11905
# RJ        Praha                2117
# ČD        Praha-Holešovice      936
#           Praha-Dejvice         125
#           Praha-Smíchov          17
# dtype: int64

# %%
df[df['kam'].str.contains('Bru')].groupby(["prodejce",'odkud']).size().nlargest()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\183660862.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df[df['kam'].str.contains('Bru')].groupby(["prodejce",'odkud']).size().nlargest()
# prodejce  odkud
# ČD        Praha hl.n.           8037
#           Berlin Hbf            1970
#           Köln Messe/Deutz      1755
#           Praha-Holešovice       755
#           Frankfurt(Main)Hbf      82
# dtype: int64

# %%
df[df['odkud'].str.contains('Prah')].groupby(["prodejce",'kam']).size().nlargest(100).dropna()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\1416979180.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df[df['odkud'].str.contains('Prah')].groupby(["prodejce",'kam']).size().nlargest(100).dropna()
# prodejce  kam
# ČD        Brno hl.n.                                 56255
#           Ostrava hl.n.                              33292
# RJ        Brno                                       16457
# ČD        Bratislava hl.st.                          11438
#           Wien Hbf                                   10433
#           Warszawa Centralna                          8884
#           Bruxelles-Midi                              8733
# RJ        Ostrava                                     8397
# ČD        Budapest-Nyugati pu                         7936
#           Berlin Hbf (tief)                           7828
#           Budapest-Kelenföld                          6258
#           Ljubljana                                   5817
# LE        Ostrava hl.n.                               5403
#           Ostrava-Svinov                              5403
# ARR       České Budějovice                            5212
# ČD        Bern                                        4184
# ARR       Tanvald                                     3590
# ČD        Zagreb Glavni kolodvor                      2884
# RJ        Budapešť                                    2686
#           Bratislava                                  2117
# ČD        Krakow Glowny                               1727
# RJ        Vídeň                                       1564
# ČD        Bratislava-Petržalka                        1548
#           Wien Franz-Josefs-Bahnhof                   1470
#           Amsterdam Centraal                          1179
#           Berlin Hbf                                  1176
# RJ        Košice                                      1092
# ČD        Ostrava-Svinov                              1030
#           Flughafen Wien                               559
#           Berlin Südkreuz                              486
# RJ        Čop                                          364
#           Krakov                                       326
# ČD        Plzeň hl.n.                                  261
# LE        Kraków Główny                                188
# ČD        Amsterdam Zuid                               166
#           Berlin Ostbahnhof                            107
#           Warszawa Wschodnia                            92
#           Wien Stadlau                                  87
#           Wien Stadlau Frachtenbahnhof                  81
#           Bruxelles-Central                             76
#           Berlin Gesundbrunnen                          63
#           Berlin-Lichtenberg                            58
#           Budapest-Deli pu                              53
#           Krakow Business Park                          30
#           Krakow Mydlniki                               30
#           Berlin Betriebsbf Schöneweide                 22
#           Berlin Zoologischer Garten                    12
#           Berlin-Lichterfelde Ost                       11
#           Amsterdam Bijlmer ArenA                       10
#           Berlin-Grünau                                  4
# ARR       Amsterdam Bijlmer ArenA                        0
#           Amsterdam Centraal                             0
#           Amsterdam Zuid                                 0
#           Berlin Betriebsbf Schöneweide                  0
#           Berlin Gesundbrunnen                           0
#           Berlin Hbf                                     0
#           Berlin Hbf (tief)                              0
#           Berlin Ostbahnhof                              0
#           Berlin Südkreuz                                0
#           Berlin Zoologischer Garten                     0
#           Berlin-Grünau                                  0
#           Berlin-Lichtenberg                             0
#           Berlin-Lichterfelde Ost                        0
#           Bern                                           0
#           Bratislava                                     0
#           Bratislava hl.st.                              0
#           Bratislava-Petržalka                           0
#           Brno                                           0
#           Brno hl.n.                                     0
#           Bruxelles-Central                              0
#           Bruxelles-Midi                                 0
#           Budapest-Deli pu                               0
#           Budapest-Kelenföld                             0
#           Budapest-Nyugati pu                            0
#           Budapešť                                       0
#           Dresden Hbf                                    0
#           Dresden-Neustadt                               0
#           Flughafen BER - Terminal 5 (Schönefeld)        0
#           Flughafen Wien                                 0
#           Gdansk Glowny                                  0
#           Hamburg Hbf                                    0
#           Hamburg-Harburg                                0
#           Jihlava                                        0
#           Karlovy Vary                                   0
#           Karlovy Vary dolní n.                          0
#           Karlovy Vary, , terminál                       0
#           Košice                                         0
#           Krakov                                         0
#           Krakow Business Park                           0
#           Krakow Glowny                                  0
#           Krakow Mydlniki                                0
#           Kraków Główny                                  0
#           Liberec                                        0
#           Ljubljana                                      0
#           Olomouc                                        0
#           Olomouc hl.n.                                  0
#           Ostrava                                        0
#           Ostrava hl.n.                                  0
#           Ostrava-Svinov                                 0
#           Pardubice hl.n.                                0
# dtype: int64

# %%
help(irozhlas_graf)
# Out:
# Help on function irozhlas_graf in module tm3k.tm3k_utils:
#
# irozhlas_graf(carovy=[], sloupcovy=[], vodorovny=[], procenta=[], skryte=[], barvy=[], histogram=False, max_procenta=100, target='', titulek='', podtitulek='', naproti=[], osay=' ', osay2=' ', osaymin=None, osaymax=None, kredity=['zdroj dat a autorstvo', 'url odkazu'], zaokrouhleni=1, prvni=True, skladany=False, naopak=False, vzhurunohama=False, skrytnuly=False)
#     Funkce vygeneruje HighCharts graf z pandas Series (jedné nebo více).
#
#     iROZHLAS-friendly barvy:
#     - "#b2e061" světle zelená
#     - "#7eb0d5" světle modrá
#     - "#fd7f6f" světle červená
#     - "#bd7ebe" světle fialová
#     - "#ffb55a" oranžová
#     - "#ffee65" žlutá
#     - "#beb9db" levandulová
#     - "#fdcce5" skoro černá
#     - "#8bd3c7" světle tyrkysová

# %%
irozhlas_graf(carovy=[cd_varsava, rj_cop, cd_budapest, le_kosice, rj_bratislava, cd_berlin, cd_bratislava, cd_viden, rj_viden, le_krakov], skryte=[rj_cop, le_kosice, le_krakov, cd_budapest], target='ceny_mezinarodni', titulek='Střední ceny jízdného do zahraničí v závislosti na předstihu nákupu', podtitulek='Východní zobrazení vybírá jízdenky do hlavních měst okolních zemí, další spoje lze rozkliknout níže.', kredity=['Zdroj dat: e-shopy dopravců v listopadu 2024. Vizualizace: iROZHLAS.cz','https://www.irozhlas.cz/zpravy-tag/datova-zurnalistika'])
# Out:
# Graf uložen.

# %%
df.groupby(['prodejce','odkud','kam']).size().nlargest(100)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\720447373.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['prodejce','odkud','kam']).size().nlargest(100)
# prodejce  odkud                          kam
# ČD        Praha hl.n.                    Brno hl.n.                       54758
#           Brno hl.n.                     Praha hl.n.                      52897
#           Praha hl.n.                    Ostrava hl.n.                    31760
#           Ostrava hl.n.                  Praha hl.n.                      25799
# RJ        Brno                           Praha                            18129
#           Praha                          Brno                             16457
#           Ostrava                        Praha                            10865
# ČD        Praha hl.n.                    Bratislava hl.st.                10357
#                                          Wien Hbf                          9751
# ARR       Liberec                        Pardubice hl.n.                   9135
#           Pardubice hl.n.                Liberec                           8985
# ČD        Brno hl.n.                     Hamburg Hbf                       8784
#           Praha hl.n.                    Warszawa Centralna                8628
# RJ        Praha                          Ostrava                           8397
# ČD        Praha hl.n.                    Bruxelles-Midi                    7961
#           Berlin Hbf (tief)              Praha hl.n.                       7732
#           Bratislava hl.st.              Praha hl.n.                       7683
#           Praha hl.n.                    Budapest-Nyugati pu               7149
#                                          Berlin Hbf (tief)                 7111
#           Ústí n.L.hl.n.                 Dresden Hbf                       7083
#           Olomouc hl.n.                  Przemysl Gl.                      6685
#           Karlovy Vary                   Ostrava hl.n.                     6499
#           Praha hl.n.                    Budapest-Kelenföld                6209
#           Wien Hbf                       Praha hl.n.                       6031
# ARR       Liberec                        Ústí nad Labem hlavní nádraží     5350
# ČD        Brno hl.n.                     Ljubljana                         5337
#           Praha hl.n.                    Ljubljana                         5291
# LE        Praha hl.n.                    Ostrava hl.n.                     5226
#                                          Ostrava-Svinov                    5226
# ARR       Praha hl.n.                    České Budějovice                  5212
# ČD        Pardubice hl.n.                Košice                            5201
#           Warszawa Centralna             Praha hl.n.                       5195
# LE        Ostrava hl.n.                  Praha hl.n.                       5048
#           Ostrava-Svinov                 Praha hl.n.                       5048
# ČD        Slavonice                      Plzeň hl.n.                       4833
# ARR       Ústí nad Labem hlavní nádraží  Liberec                           4765
#           České Budějovice               Praha hl.n.                       4726
# RJ        Brno                           Vídeň                             4590
# ČD        Budapest-Nyugati pu            Praha hl.n.                       4534
# ARR       Tanvald                        Praha hl.n.                       4460
# ČD        Bruxelles-Midi                 Praha hl.n.                       4264
#           Ostrava hl.n.                  Gdansk Glowny                     4098
#           Plzeň hl.n.                    Ostrava hl.n.                     3915
#           Praha hl.n.                    Bern                              3781
#           Liberec                        Salzburg Hbf                      3711
# RJ        Ostrava                        Brno                              3705
# ARR       Praha hl.n.                    Tanvald                           3590
# RJ        Brno                           Ostrava                           3548
# ČD        Budapest-Kelenföld             Praha hl.n.                       3527
# RJ        Vídeň                          Brno                              3479
# ČD        České Budějovice               Plzeň hl.n.                       2882
#           Dresden Hbf                    Ústí n.L.hl.n.                    2876
# RJ        Praha                          Budapešť                          2686
# ČD        Znojmo                         Jihlava                           2646
#           Praha hl.n.                    Zagreb Glavni kolodvor            2286
# RJ        Praha                          Bratislava                        2117
# ČD        Ljubljana                      Praha hl.n.                       1983
#           Berlin Hbf                     Warszawa Centralna                1960
#           České Budějovice               Zürich HB                         1950
#           Berlin Hbf                     Bruxelles-Midi                    1945
#           Plzeň hl.n.                    Slavonice                         1906
#           Köln Messe/Deutz               Bruxelles-Midi                    1751
#           Ljubljana                      Brno hl.n.                        1689
#           Praha hl.n.                    Krakow Glowny                     1612
# RJ        Praha                          Vídeň                             1564
# ČD        Praha hl.n.                    Bratislava-Petržalka              1548
#           Praha-Holešovice               Brno hl.n.                        1467
#           Praha hl.n.                    Wien Franz-Josefs-Bahnhof         1465
#           München Hbf Gl.27-36           Bern                              1462
#           Krakow Glowny                  Praha hl.n.                       1441
#           Hamburg Hbf                    Brno hl.n.                        1404
#           Praha-Holešovice               Ostrava hl.n.                     1389
#           Brno hl.n.                     Praha-Holešovice                  1376
#           Bern                           Praha hl.n.                       1353
# RJ        Vídeň                          Praha                             1290
# ČD        Harmica                        Zagreb Glavni kolodvor            1286
#           Berlin Hbf                     Amsterdam Centraal                1265
#           Ostrava hl.n.                  Karlovy Vary                      1196
#           Praha hl.n.                    Berlin Hbf                        1176
# RJ        Bratislava                     Praha                             1136
# ČD        Praha hl.n.                    Amsterdam Centraal                1106
# RJ        Praha                          Košice                            1092
# ČD        Praha hl.n.                    Ostrava-Svinov                    1030
#           Ostrava hl.n.                  Praha-Holešovice                   938
#           Praha-Holešovice               Bratislava hl.st.                  936
#           Wien Franz-Josefs-Bahnhof      Praha hl.n.                        925
#           Ostrava-Svinov                 Praha hl.n.                        917
#           Gdansk Glowny                  Ostrava hl.n.                      853
#           Köln Messe/Deutz Gl.11-12      Praha hl.n.                        841
#           Košice                         Pardubice hl.n.                    827
# LE        Pardubice hl.n.                Košice                             792
#           Košice                         Pardubice hl.n.                    768
# ČD        Praha-Holešovice               Budapest-Nyugati pu                762
#                                          Bruxelles-Midi                     755
#           Budapest-Deli pu               Praha hl.n.                        744
# RJ        Budapešť                       Praha                              719
# ČD        Berlin Hbf                     Praha hl.n.                        694
#           Praha-Holešovice               Berlin Hbf (tief)                  683
#                                          Wien Hbf                           644
#           Berlin Hbf (tief)              Praha-Holešovice                   624
# dtype: int64

# %%
df[df['odkud'].str.contains('Prah') & df['kam'].str.contains('Brux')]
# Out:
#                oscrapovano prodejce        odkud             kam  \
# 32582  2024-11-02 22:54:46       ČD  Praha hl.n.  Bruxelles-Midi
# 32583  2024-11-02 22:54:46       ČD  Praha hl.n.  Bruxelles-Midi
# 32584  2024-11-02 22:54:46       ČD  Praha hl.n.  Bruxelles-Midi
# 32585  2024-11-02 22:54:46       ČD  Praha hl.n.  Bruxelles-Midi
# 32586  2024-11-02 22:54:46       ČD  Praha hl.n.  Bruxelles-Midi
# ...                    ...      ...          ...             ...
# 614000 2024-11-19 22:00:00       ČD  Praha hl.n.  Bruxelles-Midi
# 614001 2024-11-19 22:00:00       ČD  Praha hl.n.  Bruxelles-Midi
# 614002 2024-11-19 22:00:00       ČD  Praha hl.n.  Bruxelles-Midi
# 614003 2024-11-19 22:00:00       ČD  Praha hl.n.  Bruxelles-Midi
# 614004 2024-11-19 22:00:00       ČD  Praha hl.n.  Bruxelles-Midi
#
#                     odjezd         predstih  predstih_d   predstih_h    cena  \
# 32582  2024-11-03 10:28:00  0 days 11:33:14           0    11.553889     NaN
# 32583  2024-11-03 18:28:00  0 days 19:33:14           0    19.553889  6244.0
# 32584  2024-11-03 18:05:00  0 days 19:10:14           0    19.170556     NaN
# 32585  2024-11-03 12:28:00  0 days 13:33:14           0    13.553889  6244.0
# 32586  2024-11-03 08:23:00  0 days 09:28:14           0     9.470556  7322.0
# ...                    ...              ...         ...          ...     ...
# 614000 2024-12-31 08:35:00 41 days 10:35:00          41   994.583333  7322.0
# 614001 2024-12-31 18:28:00 41 days 20:28:00          41  1004.466667  6244.0
# 614002 2025-01-01 08:35:00 42 days 10:35:00          42  1018.583333  7322.0
# 614003 2025-01-02 15:35:00 43 days 17:35:00          43  1049.583333     NaN
# 614004 2024-12-31 14:33:00 41 days 16:33:00          41  1000.550000     NaN
#
#        prostredek  volnych_mist  \
# 32582        vlak           NaN
# 32583        vlak           NaN
# 32584        vlak           NaN
# 32585        vlak           NaN
# 32586        vlak           NaN
# ...           ...           ...
# 614000       vlak           NaN
# 614001       vlak           NaN
# 614002       vlak           NaN
# 614003       vlak           NaN
# 614004       vlak           NaN
#
#                                                obsazenost  jizdni_doba  \
# 32582   [Téměr vyprodaná místa k sezení, Téměr vyproda...        667.0
# 32583   [Předpokládané vysoké obsazení - doporučujeme ...        907.0
# 32584                      [Předpokládané nízké obsazení]        922.0
# 32585   [Téměr vyprodaná místa k sezení, Téměr vyproda...        667.0
# 32586   [Předpokládané střední obsazení - doporučujeme...        672.0
# ...                                                   ...          ...
# 614000  [Předpokládané střední obsazení - doporučujeme...        660.0
# 614001  [Předpokládané střední obsazení - doporučujeme...        907.0
# 614002  [Předpokládané střední obsazení - doporučujeme...        660.0
# 614003  [Předpokládané střední obsazení - doporučujeme...       1020.0
# 614004  [Předpokládané střední obsazení - doporučujeme...       1159.0
#
#         vzdalenost         zpozdeni cena_poznamka den  prestupy  \
# 32582          NaN     [0, 0, 0, 0]  Zjistit cenu  ne         3
# 32583          NaN        [0, 0, 0]          None  ne         2
# 32584          NaN              [0]          None  ne         0
# 32585          NaN     [0, 0, 0, 0]          None  ne         3
# 32586          NaN  [0, 0, 0, 0, 0]          None  ne         4
# ...            ...              ...           ...  ..       ...
# 614000         NaN     [0, 0, 0, 0]          None  út         3
# 614001         NaN        [0, 0, 0]          None  út         2
# 614002         NaN     [0, 0, 0, 0]          None  st         3
# 614003         NaN        [0, 0, 0]  Zjistit cenu  čt         2
# 614004         NaN           [0, 0]  Zjistit cenu  út         1
#
#                                                     vlaky mistenka_zdarma  \
# 32582   [EC 174 Berliner, IC 2442, ICE 79, ICE 10 ICE ...            None
# 32583   [EC 458 Canopus, RB 15537, ICE 18 ICE Internat...            None
# 32584                           [ES 452 European Sleeper]            None
# 32585   [EC 378 Berliner, IC 2444, ICE 1171, ICE 318 I...            None
# 32586   [IC 564 Západní expres, Sp 5284, RE 3406, ICE ...            None
# ...                                                   ...             ...
# 614000  [IC 564 Západní expres, Sp 5284, ICE 28, ICE 1...            None
# 614001  [EC 458 Canopus, ICE 699, ICE 18 ICE Internati...            None
# 614002  [IC 564 Západní expres, Sp 5284, ICE 28, ICE 1...            None
# 614003        [EC 352 Bavorský expres, ICE 618, THA 9414]            None
# 614004                          [EC 172 Hungaria, NJ 424]            None
#
#        nahradni_bus  volna_mista_economy  volna_mista_economy_plus  \
# 32582          None                  NaN                       NaN
# 32583          None                  NaN                       NaN
# 32584          None                  NaN                       NaN
# 32585          None                  NaN                       NaN
# 32586          None                  NaN                       NaN
# ...             ...                  ...                       ...
# 614000         None                  NaN                       NaN
# 614001         None                  NaN                       NaN
# 614002         None                  NaN                       NaN
# 614003         None                  NaN                       NaN
# 614004         None                  NaN                       NaN
#
#         volna_mista_economy_business  volna_mista_premium
# 32582                            NaN                  NaN
# 32583                            NaN                  NaN
# 32584                            NaN                  NaN
# 32585                            NaN                  NaN
# 32586                            NaN                  NaN
# ...                              ...                  ...
# 614000                           NaN                  NaN
# 614001                           NaN                  NaN
# 614002                           NaN                  NaN
# 614003                           NaN                  NaN
# 614004                           NaN                  NaN
#
# [8809 rows x 25 columns]

# %%
filtr('ČD','Praha hl.n.','Bruxelles-Midi')
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 657.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]
# Empty DataFrame
# Columns: [oscrapovano, prodejce, odkud, kam, odjezd, predstih, predstih_d, predstih_h, cena, prostredek, volnych_mist, obsazenost, jizdni_doba, vzdalenost, zpozdeni, cena_poznamka, den, prestupy, vlaky, mistenka_zdarma, nahradni_bus, volna_mista_economy, volna_mista_economy_plus, volna_mista_economy_business, volna_mista_premium]
# Index: []

# %%
cd_berlin = filtr("ČD","Praha hl.n.","Berlin Hbf")
cd_berlin = pd.Series(cd_berlin.groupby('predstih_d')['cena'].agg(lambda x: [x.max(), x.min(), x.median()]), name="ČD Praha-Berlín").head(60)
cd_vars = filtr("ČD","Praha hl.n.","Warszawa Centralna")
cd_vars = pd.Series(cd_vars.groupby('predstih_d')['cena'].agg(lambda x: [x.max(), x.min(), x.median()]), name="ČD Praha-Varšava").head(60)
cd_vid = filtr("ČD","Praha hl.n.","Wien Hbf")
cd_vid = pd.Series(cd_vid.groupby('predstih_d')['cena'].agg(lambda x: [x.max(), x.min(), x.median()]), name="ČD Praha-Vídeň").head(60)
rj_vid = filtr("RJ","Praha","Víde")
rj_vid = pd.Series(rj_vid.groupby('predstih_d')['cena'].agg(lambda x: [x.max(), x.min(), x.median()]), name="RJ Praha-Vídeň").head(60)
cd_brat = filtr("ČD","Praha hl.n.","Bratislava hl.st.")
cd_brat = pd.Series(cd_brat.groupby('predstih_d')['cena'].agg(lambda x: [x.max(), x.min(), x.median()]), name="ČD Praha-Bratislava").head(60)
rj_brat = filtr("RJ","Praha","Bratislava")
rj_brat = pd.Series(rj_brat.groupby('predstih_d')['cena'].agg(lambda x: [x.max(), x.min(), x.median()]), name="RJ Praha-Bratislava").head(60)
le_krak = filtr("LE","Praha","Krak")
le_krak = pd.Series(le_krak.groupby('predstih_d')['cena'].agg(lambda x: [x.max(), x.min(), x.median()]), name="LE Praha-Krakov").head(60)
rj_cop = filtr('RJ','Praha','Čop')
rj_cop = pd.Series(rj_cop.groupby('predstih_d')['cena'].agg(lambda x: [x.max(), x.min(), x.median()]), name="RJ Praha-Čop").head(60)
cd_brn = filtr('ČD','Praha hl.n.','Bern')
cd_brn = pd.Series(cd_brn.groupby('predstih_d')['cena'].agg(lambda x: [x.max(), x.min(), x.median()]), name="ČD Praha-Bern").head(60)
rj_buda = filtr('RJ','Praha','Budap')
rj_buda = pd.Series(rj_buda.groupby('predstih_d')['cena'].agg(lambda x: [x.max(), x.min(), x.median()]), name="RJ Praha-Budapešť").head(60)
ukazat = [cd_berlin, cd_vars, cd_brat, rj_brat, cd_vid, rj_vid, le_kosi, rj_cop, cd_buda, rj_buda, cd_brn, le_krak]
len(ukazat)
for u in ukazat:
    u.index = u.index.map(lambda x: f"{x} d")
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 247.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 479.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 241.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 238.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 253.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 250.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 344.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 645.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]
# Nejmenší počet přestupů: 1.
# Nejrychlejší jízdní doba: 678.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 399.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]

# %%
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 479.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]

# %%
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 241.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]

# %%
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 238.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]

# %%
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 253.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]

# %%
cd_buda = filtr("ČD","Praha hl.n.","Budap")
cd_buda = pd.Series(cd_buda.groupby('predstih_d')['cena'].agg(lambda x: [x.max(), x.min(), x.median()]), name="ČD Praha-Budapešť").head(60)
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 401.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]

# %%
cd_buda = filtr("ČD","Praha hl.n.","Budap")
cd_buda = pd.Series(cd_buda.groupby('predstih_d')['cena'].agg(lambda x: [x.max(), x.min(), x.median()]), name="ČD Praha-Budapešť").head(60)
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 401.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]

# %%
le_kosi = filtr("LE","Pardubice","Košic")
le_kosi = pd.Series(le_kosi.groupby('predstih_d')['cena'].agg(lambda x: [x.max(), x.min(), x.median()]), name="LE Pardubice-Košice").head(60)
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 428.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]

# %%
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 344.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]

# %%
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 250.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]

# %%
# Out:
# Nejmenší počet přestupů: 0.
# Nejrychlejší jízdní doba: 645.0 min.
# C:\Users\micha\AppData\Local\Temp\ipykernel_17028\2559701314.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfc = dfc[(dfc['prestupy'] == minimum_prestupu) & (df['jizdni_doba'] <= (minimum_casu * nasobek))]

# %%
def irozhlas_graf(
    carovy=[],
    sloupcovy=[],
    vodorovny=[],
    rozpeti=[],
    procenta=[],
    skryte=[],
    barvy=[],
    histogram=False,
    max_procenta=100,
    target="",
    titulek="",
    podtitulek="",
    naproti=[],
    osay=" ",
    osay2=" ",
    osaymin=None,
    osaymax=None,
    kredity=["zdroj dat a autorstvo", "url odkazu"],
    zaokrouhleni=1,
    prvni=True,
    skladany=False,
    naopak=False,
    vzhurunohama=False,
    skrytnuly=False,
):
    """
    Funkce vygeneruje HighCharts graf z pandas Series (jedné nebo více).

    iROZHLAS-friendly barvy:
    - "#b2e061" světle zelená
    - "#7eb0d5" světle modrá
    - "#fd7f6f" světle červená
    - "#bd7ebe" světle fialová
    - "#ffb55a" oranžová
    - "#ffee65" žlutá
    - "#beb9db" levandulová
    - "#fdcce5" skoro černá
    - "#8bd3c7" světle tyrkysová
    """

    import os
    import pandas as pd
    from highcharts_core.chart import Chart
    from highcharts_core.options.series.area import LineSeries
    from highcharts_core.options.series.bar import ColumnSeries
    from highcharts_core.options.series.bar import BarSeries
    from highcharts_core.options.series.area import AreaRangeSeries
    from highcharts_core.options.series.histogram import HistogramSeries
    from highcharts_core.options.legend import Legend
    from highcharts_core.options.title import Title
    from highcharts_core.options.subtitle import Subtitle
    from highcharts_core.options.credits import Credits

    nastaveni = {}

    if prvni:
        zdrojaky = f"""<script src="https://code.highcharts.com/highcharts.js"></script><script src="https://code.highcharts.com/highcharts-more.js"></script><script src="https://code.highcharts.com/modules/exporting.js"></script><script src="https://code.highcharts.com/modules/export-data.js"></script><script src="https://code.highcharts.com/modules/accessibility.js"></script><style type="text/css">text{{font-family:"Asap"!important}}.paragraph{{font-family:"Noticia text"!important}}.href{{color:#666;fill:#666}}.highcharts-title{{font-family:"Noticia text"!important;font-weight:700!important;text-align:left!important;left:10px!important}}.highcharts-subtitle{{text-align:left!important;font-size:.95rem!important;left:10px!important;font-family:"Asap"!important}}.highcharts-data-labels text{{font-size:.85rem!important}}.highcharts-axis-labels text{{font-size:.85rem!important}}text.highcharts-plot-line-label{{font-size:.85rem!important;fill:#666}}text.highcharts-plot-band-label{{font-size:.85rem!important;fill:#666}}text.highcharts-credits{{font-size:.75rem!important}}.highcharts-tooltip span{{font-family:"Asap"!important}}.axis-label-on-tick{{fill:#aaa;color:#aaa}}.mock-empty-line{{fill:#fff;color:#fff}}</style>"""
    else:
        zdrojaky = ""

    pred = f"""{zdrojaky}
        <figure id="{target}">
        <div id="container"></div>
        </figure>
        <script>"""

    if len(carovy) > 0:
        categories = carovy[0].index.to_list()
    if len(sloupcovy) > 0:
        categories = sloupcovy[0].index.to_list()
    if len(vodorovny) > 0:
        categories = vodorovny[0].index.to_list()
    if len(rozpeti) > 0:
        categories = rozpeti[0].index.to_list()

    categories = [str(x) for x in categories]

    nastaveni["xAxis"] = {"categories": categories, "min": 0}
    nastaveni["yAxis"] = [
        {
            "title": {"text": osay},
            "reversed": vzhurunohama,
            "max": osaymax,
            "min": osaymin,
        }
    ]

    if skladany:
        if len(sloupcovy) > 0:
            nastaveni["plotOptions"] = {"column": {"stacking": "normal"}}
        if len(vodorovny) > 0:
            nastaveni["plotOptions"] = {"bar": {"stacking": "normal"}}
    if histogram:
        nastaveni["plotOptions"] = {
            "column": {
                "pointPadding": 0,
                "borderWidth": 0,
                "groupPadding": 0,
                "shadow": False,
            }
        }

    
    if len(procenta) > 0:
        osa_procent = {
            "title": {"text": osay2},
            "max": max_procenta,
            "min": 0,
            "labels": {"format": "{value} %"},
        }

        if len(procenta) != len(carovy) + len(sloupcovy):
            osa_procent["opposite"] = True
            druha_osa = 1
            nastaveni["yAxis"].append(osa_procent)
            nastaveni["alignTicks"] = False
        if len(procenta) == len(carovy) + len(sloupcovy):
            nastaveni["yAxis"] = [osa_procent]
            druha_osa = 0

    if len(naproti) > 0:
        druha_osa = 1
        druha_osa_y = {
            "title": {"text": osay2},
            "opposite": True,
            "max": naproti[0].max(),
            "min": 0,
        }
        nastaveni["yAxis"].append(druha_osa_y)

    my_chart = Chart(container=target, options=nastaveni)

    procenta = [p.name for p in procenta]
    naproti = [n.name for n in naproti]
    skryte = [s.name for s in skryte]

    def vykresleni(serie, typ):
        for s in serie:
            popisek = s.name

            if s.name in skryte:
                viditelnost = False
            else:
                viditelnost = True

            ktera_osa = 0
            if s.name in naproti:
                ktera_osa = druha_osa

            if s.name in procenta:
                s = [round(x * 100, zaokrouhleni) for x in s.fillna(0).to_list()]
                my_chart.add_series(
                    typ(
                        data=s,
                        visible=viditelnost,
                        name=popisek,
                        y_axis=druha_osa,
                        tooltip={"valueSuffix": " %"},
                    )
                )

            else:
                my_chart.add_series(
                    typ(
                        data=s.fillna(0).to_list(),
                        visible=viditelnost,
                        name=popisek,
                        y_axis=ktera_osa,
                    )
                )

    if len(sloupcovy) > 0:
        vykresleni(sloupcovy, ColumnSeries)
    if len(carovy) > 0:
        vykresleni(carovy, LineSeries)
    if len(vodorovny) > 0:
        vykresleni(vodorovny, BarSeries)
    if len(rozpeti) > 0:
        print("jsem delší")
        vykresleni(rozpeti, AreaRangeSeries)  

    if len(barvy) > 0:
        my_chart.options.colors = barvy
    else:
        my_chart.options.colors = colors = [
            "#b2e061",  ## světle zelená (light green)
            "#7eb0d5",  ## světle modrá (light blue)
            "#fd7f6f",  ## světle červená (light red)
            "#bd7ebe",  ## světle fialová (light purple)
            "#ffb55a",  ## oranžová (orange)
            "#ffee65",  ## žlutá (yellow)
            "#beb9db",  ## levandulová (lavender)
            "#fdcce5",  ## skoro černá
            "#8bd3c7",  ## světle tyrkysová (light turquoise)
        ]

    if naopak:
        my_chart.options.legend = Legend(reversed=True)

    my_chart.options.title = Title(text=titulek, align="left", margin=30)

    if len(podtitulek) > 0:
        my_chart.options.subtitle = Subtitle(text=podtitulek, align="left")

    my_chart.options.credits = Credits(text=kredity[0], enabled=True, href=kredity[1])

    as_js_literal = my_chart.to_js_literal()

    if skrytnuly == True:
        as_js_literal = as_js_literal.replace("y: 0.0", "y: null")

    code = f"<html><head><title>{titulek}</title></head><body>{pred}{as_js_literal}</script></body></html>"

    if not os.path.exists("grafy"):
        os.mkdir("grafy")

    with open(os.path.join("grafy", target + ".html"), "w+") as f:
        f.write(code)

    with open(os.path.join("grafy", target + ".txt"), "w+") as f:
        f.write(f"{pred}{as_js_literal}</script>")

        print("Graf uložen.")

# %%
def irozhlas_graf(
    carovy=[],
    sloupcovy=[],
    vodorovny=[],
    rozpeti=[],
    procenta=[],
    skryte=[],
    barvy=[
            "#b2e061",  ## světle zelená (light green)
            "#7eb0d5",  ## světle modrá (light blue)
            "#fd7f6f",  ## světle červená (light red)
            "#bd7ebe",  ## světle fialová (light purple)
            "#ffb55a",  ## oranžová (orange)
            "#ffee65",  ## žlutá (yellow)
            "#beb9db",  ## levandulová (lavender)
            "#fdcce5",  ## skoro černá
            "#8bd3c7",  ## světle tyrkysová (light turquoise),
        "red",
        "blue",
        "purple"
        ],
    histogram=False,
    max_procenta=100,
    target="",
    titulek="",
    podtitulek="",
    naproti=[],
    osay=" ",
    osay2=" ",
    osaymin=None,
    osaymax=None,
    kredity=["zdroj dat a autorstvo", "url odkazu"],
    zaokrouhleni=1,
    prvni=True,
    skladany=False,
    naopak=False,
    vzhurunohama=False,
    skrytnuly=False,
):
    """
    Funkce vygeneruje HighCharts graf z pandas Series (jedné nebo více).

    iROZHLAS-friendly barvy:
    - "#b2e061" světle zelená
    - "#7eb0d5" světle modrá
    - "#fd7f6f" světle červená
    - "#bd7ebe" světle fialová
    - "#ffb55a" oranžová
    - "#ffee65" žlutá
    - "#beb9db" levandulová
    - "#fdcce5" skoro černá
    - "#8bd3c7" světle tyrkysová
    """

    import os
    import pandas as pd
    from highcharts_core.chart import Chart
    from highcharts_core.options.series.area import LineSeries
    from highcharts_core.options.series.bar import ColumnSeries
    from highcharts_core.options.series.bar import BarSeries
    from highcharts_core.options.series.area import AreaRangeSeries
    from highcharts_core.options.series.histogram import HistogramSeries
    from highcharts_core.options.legend import Legend
    from highcharts_core.options.title import Title
    from highcharts_core.options.subtitle import Subtitle
    from highcharts_core.options.credits import Credits

    pocitadlo_barev = 0
    
    nastaveni = {}

    if prvni:
        zdrojaky = f"""<script src="https://code.highcharts.com/highcharts.js"></script><script src="https://code.highcharts.com/highcharts-more.js"></script><script src="https://code.highcharts.com/modules/exporting.js"></script><script src="https://code.highcharts.com/modules/export-data.js"></script><script src="https://code.highcharts.com/modules/accessibility.js"></script><style type="text/css">text{{font-family:"Asap"!important}}.paragraph{{font-family:"Noticia text"!important}}.href{{color:#666;fill:#666}}.highcharts-title{{font-family:"Noticia text"!important;font-weight:700!important;text-align:left!important;left:10px!important}}.highcharts-subtitle{{text-align:left!important;font-size:.95rem!important;left:10px!important;font-family:"Asap"!important}}.highcharts-data-labels text{{font-size:.85rem!important}}.highcharts-axis-labels text{{font-size:.85rem!important}}text.highcharts-plot-line-label{{font-size:.85rem!important;fill:#666}}text.highcharts-plot-band-label{{font-size:.85rem!important;fill:#666}}text.highcharts-credits{{font-size:.75rem!important}}.highcharts-tooltip span{{font-family:"Asap"!important}}.axis-label-on-tick{{fill:#aaa;color:#aaa}}.mock-empty-line{{fill:#fff;color:#fff}}</style>"""
    else:
        zdrojaky = ""

    pred = f"""{zdrojaky}
        <figure id="{target}">
        <div id="container"></div>
        </figure>
        <script>"""

    if len(carovy) > 0:
        categories = carovy[0].index.to_list()
    if len(sloupcovy) > 0:
        categories = sloupcovy[0].index.to_list()
    if len(vodorovny) > 0:
        categories = vodorovny[0].index.to_list()
    if len(rozpeti) > 0:
        categories = rozpeti[0].index.to_list()

    categories = [str(x) for x in categories]

    nastaveni["xAxis"] = {"categories": categories, "min": 0}
    nastaveni["yAxis"] = [
        {
            "title": {"text": osay},
            "reversed": vzhurunohama,
            "max": osaymax,
            "min": osaymin,
        }
    ]

    if skladany:
        if len(sloupcovy) > 0:
            nastaveni["plotOptions"] = {"column": {"stacking": "normal"}}
        if len(vodorovny) > 0:
            nastaveni["plotOptions"] = {"bar": {"stacking": "normal"}}
    if histogram:
        nastaveni["plotOptions"] = {
            "column": {
                "pointPadding": 0,
                "borderWidth": 0,
                "groupPadding": 0,
                "shadow": False,
            }
        }

    
    if len(procenta) > 0:
        osa_procent = {
            "title": {"text": osay2},
            "max": max_procenta,
            "min": 0,
            "labels": {"format": "{value} %"},
        }

        if len(procenta) != len(carovy) + len(sloupcovy):
            osa_procent["opposite"] = True
            druha_osa = 1
            nastaveni["yAxis"].append(osa_procent)
            nastaveni["alignTicks"] = False
        if len(procenta) == len(carovy) + len(sloupcovy):
            nastaveni["yAxis"] = [osa_procent]
            druha_osa = 0

    if len(naproti) > 0:
        druha_osa = 1
        druha_osa_y = {
            "title": {"text": osay2},
            "opposite": True,
            "max": naproti[0].max(),
            "min": 0,
        }
        nastaveni["yAxis"].append(druha_osa_y)

    my_chart = Chart(container=target, options=nastaveni)

    procenta = [p.name for p in procenta]
    naproti = [n.name for n in naproti]
    skryte = [s.name for s in skryte]

    def vykresleni(serie, typ):

        pocitadlo_barev = 0
        
        for s in serie:
            popisek = s.name
            print(popisek)

            if s.name in skryte:
                viditelnost = False
            else:
                viditelnost = True

            ktera_osa = 0
            if s.name in naproti:
                ktera_osa = druha_osa

            if s.name in procenta:
                s = [round(x * 100, zaokrouhleni) for x in s.fillna(0).to_list()]
                my_chart.add_series(
                    typ(
                        data=s,
                        visible=viditelnost,
                        name=popisek,
                        y_axis=druha_osa,
                        tooltip={"valueSuffix": " %"},
                    )
                )

            if any(s.name == x.name for x in rozpeti):
                line_id = f"line_{popisek}"
                print(line_id)
                my_chart.add_series(
                    LineSeries(
                        data=s.apply(lambda x: x[2]).fillna(0).to_list(),
                        visible=viditelnost,
                        id = line_id,
                        name=popisek,
                        y_axis=ktera_osa,
                        color = barvy[pocitadlo_barev],
                        tooltip={"valuePrefix": "střední: ","valueSuffix": " Kč"},
                    ))
                my_chart.add_series(
                    AreaRangeSeries(
                        data=s.apply(lambda x: x[0:2]).fillna(0).to_list(),
                        visible=viditelnost,
                        type='arearange',
                        name=popisek,
                        linkedto = line_id,
                        y_axis=ktera_osa,
                        color = barvy[pocitadlo_barev],
                        fillOpacity=0.3,
                        tooltip={"valueSuffix": " Kč"},
                    lineWidth=0,
                    marker={"enabled": False}
                    ))
                pocitadlo_barev += 1

   #         else:
                #my_chart.add_series(
                    #typ(
                     #   data=s.fillna(0).to_list(),
                    #    visible=viditelnost,
                   #     name=popisek,
                  #      y_axis=ktera_osa,
                 #   )
                #)

    if len(sloupcovy) > 0:
        vykresleni(sloupcovy, ColumnSeries)
    if len(carovy) > 0:
        vykresleni(carovy, LineSeries)
    if len(vodorovny) > 0:
        vykresleni(vodorovny, BarSeries)
    if len(rozpeti) > 0:
        vykresleni(rozpeti, AreaRangeSeries)

    my_chart.options.colors = barvy

    if naopak:
        my_chart.options.legend = Legend(reversed=True)

    my_chart.options.title = Title(text=titulek, align="left", margin=30)

    if len(podtitulek) > 0:
        my_chart.options.subtitle = Subtitle(text=podtitulek, align="left")

    my_chart.options.credits = Credits(text=kredity[0], enabled=True, href=kredity[1])

    as_js_literal = my_chart.to_js_literal()

    if skrytnuly == True:
        as_js_literal = as_js_literal.replace("y: 0.0", "y: null")

 #   if len(rozpeti) > 0:
    
  #      as_js_literal = as_js_literal.replace(
   #         '"type":"arearange"', 
    #        '"type":"arearange", "linkedTo": "previous", "fillOpacity": 0.3, "lineWidth": 0, "marker": {"enabled": false}'
     #   )

    
#    if len(rozpeti) > 0:
#        as_js_literal = as_js_literal.replace("type: 'arearange'", "type: 'arearange',linkedTo: 'previous',fillOpacity: 0.3,lineWidth: 0,marker: {enabled: false}")

    as_js_literal = as_js_literal.splitlines()

    as_js_literal2 = []
    
    for line in as_js_literal:
        if 'id: ' in line:
            ajdy = line.split("'")[1]
            print(ajdy)
        if "type: 'arearange'" in line:
            line = line.replace(" type: 'arearange'",f" type: 'arearange',linkedTo: '{ajdy}', fillOpacity: 0.3, lineWidth: 0")
        as_js_literal2.append(line)
    as_js_literal2 = "\n".join(as_js_literal2)
    
    code = f"<html><head><title>{titulek}</title></head><body>{pred}{as_js_literal2}</script></body></html>"

    
    if not os.path.exists("grafy"):
        os.mkdir("grafy")

    with open(os.path.join("grafy", target + ".html"), "w+") as f:
        f.write(code)

    with open(os.path.join("grafy", target + ".txt"), "w+") as f:
        f.write(f"{pred}{as_js_literal}</script>")

        print("Graf uložen.")

# %%
# xx = pd.Series(df.sample(30).groupby('predstih_d')['cena'].agg(lambda x: [x.max(), x.min()]), name='pokus')

# %%
xx
# Out:
# predstih_d
# 0      [903.0, 465.0]
# 1     [1548.0, 274.0]
# 2      [439.0, 305.0]
# 3          [nan, nan]
# 4      [469.0, 369.0]
# 5     [5655.0, 305.0]
# 6      [645.0, 369.0]
# 7      [359.0, 359.0]
# 8      [585.0, 585.0]
# 9      [369.0, 369.0]
# 10     [249.0, 249.0]
# 12    [2495.0, 299.0]
# 14     [329.0, 329.0]
# 16     [305.0, 305.0]
# 19     [289.0, 289.0]
# Name: pokus, dtype: object

# %%
xx2 = pd.Series(xx.sample(10), name="hahaha")

# %%
ukazat[0]
# Out:
# predstih_d
# 0 d     [2172.0, 877.0, 1522.0]
# 1 d     [2172.0, 877.0, 1006.0]
# 2 d     [2172.0, 748.0, 1006.0]
# 3 d     [2172.0, 387.0, 1006.0]
# 4 d     [2172.0, 387.0, 1006.0]
# 5 d     [2172.0, 748.0, 1006.0]
# 6 d      [2172.0, 387.0, 903.0]
# 7 d      [2172.0, 387.0, 903.0]
# 8 d      [2172.0, 387.0, 903.0]
# 9 d      [2172.0, 387.0, 903.0]
# 10 d     [2172.0, 387.0, 903.0]
# 11 d    [2172.0, 387.0, 1006.0]
# 12 d    [2172.0, 387.0, 1006.0]
# 13 d    [2172.0, 387.0, 1006.0]
# 14 d     [2172.0, 387.0, 903.0]
# 15 d     [2172.0, 387.0, 903.0]
# 16 d    [2172.0, 387.0, 1006.0]
# 17 d     [2172.0, 387.0, 903.0]
# 18 d    [2172.0, 748.0, 1006.0]
# 19 d    [2172.0, 748.0, 1006.0]
# 20 d     [2172.0, 387.0, 903.0]
# 21 d     [2172.0, 387.0, 903.0]
# 22 d     [2172.0, 748.0, 903.0]
# 23 d     [2172.0, 387.0, 903.0]
# 24 d     [2172.0, 387.0, 903.0]
# 25 d     [2172.0, 748.0, 903.0]
# 26 d    [2172.0, 387.0, 1006.0]
# 27 d     [2172.0, 748.0, 903.0]
# 28 d     [2172.0, 748.0, 903.0]
# 29 d     [2172.0, 748.0, 903.0]
# 30 d     [2172.0, 387.0, 903.0]
# 31 d     [2172.0, 748.0, 903.0]
# 32 d    [2172.0, 748.0, 1006.0]
# 33 d     [2172.0, 748.0, 903.0]
# 34 d     [1006.0, 748.0, 825.5]
# 35 d      [903.0, 748.0, 825.5]
# 36 d     [1135.0, 748.0, 903.0]
# 37 d    [2172.0, 903.0, 1006.0]
# 38 d     [2172.0, 748.0, 903.0]
# 39 d     [2172.0, 387.0, 748.0]
# 40 d     [2172.0, 387.0, 748.0]
# 41 d     [2172.0, 387.0, 903.0]
# 42 d     [2172.0, 387.0, 748.0]
# 43 d     [2172.0, 387.0, 903.0]
# 44 d     [2172.0, 387.0, 748.0]
# 45 d     [2172.0, 387.0, 825.5]
# 46 d     [2172.0, 387.0, 748.0]
# 47 d     [2172.0, 387.0, 903.0]
# 48 d     [2172.0, 387.0, 748.0]
# 49 d     [2172.0, 387.0, 748.0]
# 50 d     [2172.0, 387.0, 748.0]
# 51 d     [2172.0, 387.0, 748.0]
# 52 d     [2172.0, 387.0, 748.0]
# 53 d     [2172.0, 387.0, 748.0]
# 54 d     [2172.0, 387.0, 748.0]
# 55 d     [2172.0, 387.0, 748.0]
# 56 d      [903.0, 387.0, 748.0]
# 57 d     [2172.0, 387.0, 748.0]
# 58 d     [2172.0, 387.0, 748.0]
# 59 d     [2172.0, 387.0, 748.0]
# Name: ČD Praha-Berlín, dtype: object

# %%
irozhlas_graf(rozpeti=ukazat, skryte=ukazat[1:], target='pokus', titulek='Mezistátní jízdné podle předstihu nákupu', osaymin=0, podtitulek='Srovnávají se pouze spoje s nejnižším možným počtem přestupů.', kredity=['Zdroj dat: e-shopy dopravců v listopadu 2024. Vizualizace: iROZHLAS.cz','https://www.irozhlas.cz/zpravy-tag/datova-zurnalistika'])
# Out:
# ČD Praha-Berlín
# line_ČD Praha-Berlín
# ČD Praha-Varšava
# line_ČD Praha-Varšava
# ČD Praha-Bratislava
# line_ČD Praha-Bratislava
# RJ Praha-Bratislava
# line_RJ Praha-Bratislava
# ČD Praha-Vídeň
# line_ČD Praha-Vídeň
# RJ Praha-Vídeň
# line_RJ Praha-Vídeň
# LE Pardubice-Košice
# line_LE Pardubice-Košice
# RJ Praha-Čop
# line_RJ Praha-Čop
# ČD Praha-Budapešť
# line_ČD Praha-Budapešť
# RJ Praha-Budapešť
# line_RJ Praha-Budapešť
# ČD Praha-Bern
# line_ČD Praha-Bern
# LE Praha-Krakov
# line_LE Praha-Krakov
# line_ČD Praha-Berlín
# line_ČD Praha-Varšava
# line_ČD Praha-Bratislava
# line_RJ Praha-Bratislava
# line_ČD Praha-Vídeň
# line_RJ Praha-Vídeň
# line_LE Pardubice-Košice
# line_RJ Praha-Čop
# line_ČD Praha-Budapešť
# line_RJ Praha-Budapešť
# line_ČD Praha-Bern
# line_LE Praha-Krakov
# Graf uložen.
